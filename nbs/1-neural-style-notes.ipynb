# %%
path = '../data/dancing.jpg'

# %%
from __future__ import print_function

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from PIL import Image
import matplotlib.pyplot as plt

import torchvision.transforms as transforms
import torchvision.models as models

import copy

# %%
img = Image.open(path)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=444x444 at 0x7F912017F1D0>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
imsize = 512 if torch.cuda.is_available() else 128  # use small size if no gpu

# %%
loader = transforms.Compose([
    transforms.Resize(imsize),  # scale imported image
    transforms.ToTensor()])

# %%
image = loader(img).unsqueeze(0)

# %%
x =loader(img)
type(x), x.size()
# Out:
# (torch.Tensor, torch.Size([3, 128, 128]))

# %%
type(image), image.size()
# Out:
# (torch.Tensor, torch.Size([1, 3, 128, 128]))

# %% [markdown]
# **REF** https://pytorch.org/docs/stable/torch.html#torch.unsqueeze
